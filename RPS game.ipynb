# %% [raw]
# To create the Rock, Paper and Scissors game with Python, we need to take the user’s choice and then we need to compare it with the computers choice which is taken using the random module in Python

# %%
import random
choices = ["Rock", "Paper", "Scissors"]
cpu_score = 0
player_score = 0
while True:
    player = input("Rock, Paper or  Scissors?").capitalize()
    computer = random.choice(choices)
    print('computer : ',computer+ ' \n ')
    ## Conditions of Rock,Paper and Scissors
    if player == computer:
        print("Tie!")
    elif player == "Rock":
        if computer == "Paper":
            print("You lose!", computer, "covers", player)
            cpu_score+=1
        else:
            print("You win!", player, "smashes", computer)
            player_score+=1
    elif player == "Paper":
        if computer == "Scissors":
            print("You lose!", computer, "cut", player)
            cpu_score+=1
        else:
            print("You win!", player, "covers", computer)
            player_score+=1
    elif player == "Scissors":
        if computer == "Rock":
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
    elif player=='End':
        print("Final Scores:")
        print(f"CPU:{cpu_score}")
        print(f"Plaer:{player_score}")
        break
# Out:
# Rock, Paper or  Scissors?paper
# computer :  Scissors
#
# You lose! Scissors cut Paper
# Rock, Paper or  Scissors?rock
# computer :  Rock
#
# Tie!
# Rock, Paper or  Scissors?rock
# computer :  Rock
#
# Tie!
# Rock, Paper or  Scissors?rock
# computer :  Paper
#
# You lose! Paper covers Rock
# Rock, Paper or  Scissors?rock
# computer :  Rock
#
# Tie!
# Rock, Paper or  Scissors?rock
# computer :  Scissors
#
# You win! Rock smashes Scissors
# Rock, Paper or  Scissors?rock
# computer :  Rock
#
# Tie!
# Rock, Paper or  Scissors?rock
# computer :  Scissors
#
# You win! Rock smashes Scissors
# Rock, Paper or  Scissors?rock
# computer :  Scissors
#
# You win! Rock smashes Scissors
# Rock, Paper or  Scissors?rock
# computer :  Scissors
#
# You win! Rock smashes Scissors
# Rock, Paper or  Scissors?paper
# computer :  Paper
#
# Tie!
# Rock, Paper or  Scissors?rock
# computer :  Scissors
#
# You win! Rock smashes Scissors
# Rock, Paper or  Scissors?scissors
# computer :  Rock
#
# You lose... Rock smashes Scissors
# Rock, Paper or  Scissors?rock
# computer :  Paper
#
# You lose! Paper covers Rock
# Rock, Paper or  Scissors?paper
# computer :  Rock
#
# You win! Paper covers Rock
# Rock, Paper or  Scissors?end
# computer :  Paper
#
# Final Scores:
# CPU:4
# Plaer:6
